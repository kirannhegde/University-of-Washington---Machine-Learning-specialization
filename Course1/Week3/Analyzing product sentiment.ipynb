# %% [markdown]
# ### Week 3: Programming assignment begins here(using Pandas, numpy and scikit-learn)
# ### Reference: https://medium.com/tensorist/classifying-yelp-reviews-using-nltk-and-scikit-learn-c58e71e962d9

# %%
#Importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
selected_words = ['awesome', 'great', 'fantastic', 'amazing', 'love', 'horrible', 'bad', 'terrible', 'awful', 'wow', 'hate']

# %% [markdown]
# ### Import the dataset and inspect its contents

# %%
reviews_df = pd.read_csv('amazon_baby.csv')

# %%
#Dimensions of the dataset. # of rows x # of columns
reviews_df.shape
# Out:
# (183531, 3)

# %%
reviews_df.head()
# Out:
#                                                 name  \
# 0                           Planetwise Flannel Wipes
# 1                              Planetwise Wipe Pouch
# 2                Annas Dream Full Quilt with 2 Shams
# 3  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...
#
#                                               review  rating
# 0  These flannel wipes are OK, but in my opinion ...       3
# 1  it came early and was not disappointed. i love...       5
# 2  Very soft and comfortable and warmer than it l...       5
# 3  This is a product well worth the purchase.  I ...       5
# 4  All of my kids have cried non-stop when I trie...       5

# %%
reviews_df.describe()
# Out:
#               rating
# count  183531.000000
# mean        4.120448
# std         1.285017
# min         1.000000
# 25%         4.000000
# 50%         5.000000
# 75%         5.000000
# max         5.000000

# %%
#Lets inspect the datatypes of the columns
reviews_df.dtypes
# Out:
# name      object
# review    object
# rating     int64
# dtype: object

# %%
#Fill NA in the review column which do not contain anything
reviews_df = reviews_df.fillna('')
reviews_df
# Out:
#                                                      name  \
# 0                                Planetwise Flannel Wipes
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# 5       Stop Pacifier Sucking without tears with Thumb...
# 6                A Tale of Baby\'s Days with Peter Rabbit
# 7       Baby Tracker&reg; - Daily Childcare Journal, S...
# 8       Baby Tracker&reg; - Daily Childcare Journal, S...
# 9       Baby Tracker&reg; - Daily Childcare Journal, S...
# 10      Baby Tracker&reg; - Daily Childcare Journal, S...
# 11      Baby Tracker&reg; - Daily Childcare Journal, S...
# 12      Baby Tracker&reg; - Daily Childcare Journal, S...
# 13      Baby Tracker&reg; - Daily Childcare Journal, S...
# 14        Nature\'s Lullabies First Year Sticker Calendar
# 15        Nature\'s Lullabies First Year Sticker Calendar
# 16        Nature\'s Lullabies First Year Sticker Calendar
# 17       Nature\'s Lullabies Second Year Sticker Calendar
# 18       Nature\'s Lullabies Second Year Sticker Calendar
# 19       Nature\'s Lullabies Second Year Sticker Calendar
# 20       Nature\'s Lullabies Second Year Sticker Calendar
# 21       Nature\'s Lullabies Second Year Sticker Calendar
# 22       Nature\'s Lullabies Second Year Sticker Calendar
# 23       Nature\'s Lullabies Second Year Sticker Calendar
# 24       Nature\'s Lullabies Second Year Sticker Calendar
# 25       Nature\'s Lullabies Second Year Sticker Calendar
# 26                          Baby\'s First Journal - Green
# 27                            Lamaze Peekaboo, I Love You
# 28                            Lamaze Peekaboo, I Love You
# 29                            Lamaze Peekaboo, I Love You
# ...                                                   ...
# 183501  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183502  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183503  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183504  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183505  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183506  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183507  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183508  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183509  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183510  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183511  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183512  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183513  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183514  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183515  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183516  BoogieBulb&reg; - The First True Cleanable &am...
# 183517  Baby Mucus Extractor, Nasal Aspirator From Dr....
# 183518  Baby Mucus Extractor, Nasal Aspirator From Dr....
# 183519  Baby Mucus Extractor, Nasal Aspirator From Dr....
# 183520  Baby Mucus Extractor, Nasal Aspirator From Dr....
# 183521  Airline Seat Belt Extender - The Best Extensio...
# 183522  Airline Seat Belt Extender - The Best Extensio...
# 183523  Squeasy Snacker 6oz Silicone Reusable Food Pou...
# 183524  Squeasy Snacker 6oz Silicone Reusable Food Pou...
# 183525  Squeasy Snacker 6oz Silicone Reusable Food Pou...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating
# 0       These flannel wipes are OK, but in my opinion ...       3
# 1       it came early and was not disappointed. i love...       5
# 2       Very soft and comfortable and warmer than it l...       5
# 3       This is a product well worth the purchase.  I ...       5
# 4       All of my kids have cried non-stop when I trie...       5
# 5       When the Binky Fairy came to our house, we did...       5
# 6       Lovely book, it\'s bound tightly so you may no...       4
# 7       Perfect for new parents. We were able to keep ...       5
# 8       A friend of mine pinned this product on Pinter...       5
# 9       This has been an easy way for my nanny to reco...       4
# 10      I love this journal and our nanny uses it ever...       4
# 11      This book is perfect!  I\'m a first time new m...       5
# 12      I originally just gave the nanny a pad of pape...       4
# 13      I thought keeping a simple handwritten journal...       3
# 14      Space for monthly photos, info and a lot of us...       5
# 15      I bought this calender for myself for my secon...       4
# 16      I love this little calender, you can keep trac...       5
# 17      This was the only calender I could find for th...       5
# 18      I completed a calendar for my son\'s first yea...       4
# 19      We wanted to get something to keep track of ou...       5
# 20      I had a hard time finding a second year calend...       5
# 21      I only purchased a second-year calendar for my...       2
# 22      I LOVE this calendar for recording events of m...       5
# 23      Calendar is exactly as described, but I find t...       3
# 24      Wife loves this calender. Comes with a lot of ...       5
# 25      My daughter had her 1st baby over a year ago. ...       5
# 26      Extremely useful! As a new mom, tired and inex...       5
# 27      My son loves peek a boo at this age of 9 month...       3
# 28      One of baby\'s first and favorite books, and i...       4
# 29      I like how the book has a hook to attach it to...       5
# ...                                                   ...     ...
# 183501  I received a free sample from VIPU program for...       5
# 183502  It got here incredibly fast & it is a nice dur...       5
# 183503  I got this case in the mail today, it came on ...       2
# 183504  Free caseLove it... The color was great firm h...       5
# 183505  I received a free sample from VIPU program for...       5
# 183506  This case definitely isn\'t cheap. It feels ve...       5
# 183507  got this for my wife and she loves it would de...       5
# 183508  love this case. It fit perfectly and the color...       5
# 183509  this case is the greatest very cool and stylis...       5
# 183510              Great fit. Really love how red it is.       5
# 183511  I received a free sample from VIPU program for...       3
# 183512  *I received a free sample from VIPU program fo...       5
# 183513  I was a very surprised by the quality of this ...       5
# 183514  I received a free sample from VIPU program for...       4
# 183515  I love this phone case!  My  iPhone is always ...       5
# 183516  I\'ve ordered a ton of &#34;suckers&#34; to tr...       3
# 183517  I recieved this product free of charge and abs...       5
# 183518  The tube is soft and easy to use, and the tip ...       5
# 183519  I love this so much. It works way better than ...       5
# 183520  The aspirator works well but needs to come wit...       4
# 183521  Up until recently I have hated flying, putting...       5
# 183522  I bought this as a father\'s day gift for my d...       5
# 183523  I love that these can hold purees OR liquids, ...       5
# 183524  I love this product, it makes my life easier. ...       5
# 183525  This reusable squeeze bottle is the best I hav...       5
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5
#
# [183531 rows x 3 columns]

# %%
#The review column has a datatype of object, which means that the column can contain other datatypes
#other than just strings
#https://stackoverflow.com/questions/23158447/convert-float-to-string-in-pandas
reviews_df['review'] = reviews_df['review'].astype(str)

# %%
#Find the length of each review and add a new column
reviews_df['review length'] = reviews_df['review'].apply(len)
#Inspect the dataframe again. You will see that a 4th column containing the length of the review has been added.
reviews_df.head()
# Out:
#                                                 name  \
# 0                           Planetwise Flannel Wipes
# 1                              Planetwise Wipe Pouch
# 2                Annas Dream Full Quilt with 2 Shams
# 3  Stop Pacifier Sucking without tears with Thumb...
# 4  Stop Pacifier Sucking without tears with Thumb...
#
#                                               review  rating  review length
# 0  These flannel wipes are OK, but in my opinion ...       3            452
# 1  it came early and was not disappointed. i love...       5            158
# 2  Very soft and comfortable and warmer than it l...       5            143
# 3  This is a product well worth the purchase.  I ...       5            390
# 4  All of my kids have cried non-stop when I trie...       5            405

# %% [markdown]
# ### Define what is a positive and a negative sentiment

# %%
#We will ignore 3. 4 and 5 are considered positive whereas 1,2 are considered negative.
#We will indicate a positive sentiment by 1 and negative sentiment by 0
reviews_df = reviews_df[reviews_df['rating'] != 3]
#Construct a new column which indicates the sentiment. A sentiment value of True indicates that we have a positive review
reviews_df['sentiment'] = reviews_df['rating'].apply(lambda rating: +1 if rating > 3 else -1)
reviews_df
# Out:
# C:\Users\kiranh.CITRITE\AppData\Local\Continuum\Anaconda2\envs\gl-env\lib\site-packages\ipykernel\__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                                      name  \
# 1                                   Planetwise Wipe Pouch
# 2                     Annas Dream Full Quilt with 2 Shams
# 3       Stop Pacifier Sucking without tears with Thumb...
# 4       Stop Pacifier Sucking without tears with Thumb...
# 5       Stop Pacifier Sucking without tears with Thumb...
# 6                A Tale of Baby\'s Days with Peter Rabbit
# 7       Baby Tracker&reg; - Daily Childcare Journal, S...
# 8       Baby Tracker&reg; - Daily Childcare Journal, S...
# 9       Baby Tracker&reg; - Daily Childcare Journal, S...
# 10      Baby Tracker&reg; - Daily Childcare Journal, S...
# 11      Baby Tracker&reg; - Daily Childcare Journal, S...
# 12      Baby Tracker&reg; - Daily Childcare Journal, S...
# 14        Nature\'s Lullabies First Year Sticker Calendar
# 15        Nature\'s Lullabies First Year Sticker Calendar
# 16        Nature\'s Lullabies First Year Sticker Calendar
# 17       Nature\'s Lullabies Second Year Sticker Calendar
# 18       Nature\'s Lullabies Second Year Sticker Calendar
# 19       Nature\'s Lullabies Second Year Sticker Calendar
# 20       Nature\'s Lullabies Second Year Sticker Calendar
# 21       Nature\'s Lullabies Second Year Sticker Calendar
# 22       Nature\'s Lullabies Second Year Sticker Calendar
# 24       Nature\'s Lullabies Second Year Sticker Calendar
# 25       Nature\'s Lullabies Second Year Sticker Calendar
# 26                          Baby\'s First Journal - Green
# 28                            Lamaze Peekaboo, I Love You
# 29                            Lamaze Peekaboo, I Love You
# 30                            Lamaze Peekaboo, I Love You
# 31                            Lamaze Peekaboo, I Love You
# 32                            Lamaze Peekaboo, I Love You
# 33                            Lamaze Peekaboo, I Love You
# ...                                                   ...
# 183499  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183500  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183501  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183502  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183503  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183504  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183505  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183506  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183507  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183508  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183509  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183510  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183512  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183513  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183514  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183515  Maxboost iPhone 5S/5 Case - Protective Snap-on...
# 183517  Baby Mucus Extractor, Nasal Aspirator From Dr....
# 183518  Baby Mucus Extractor, Nasal Aspirator From Dr....
# 183519  Baby Mucus Extractor, Nasal Aspirator From Dr....
# 183520  Baby Mucus Extractor, Nasal Aspirator From Dr....
# 183521  Airline Seat Belt Extender - The Best Extensio...
# 183522  Airline Seat Belt Extender - The Best Extensio...
# 183523  Squeasy Snacker 6oz Silicone Reusable Food Pou...
# 183524  Squeasy Snacker 6oz Silicone Reusable Food Pou...
# 183525  Squeasy Snacker 6oz Silicone Reusable Food Pou...
# 183526  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183527  Baby Teething Necklace for Mom Pretty Donut Sh...
# 183528   Abstract 2 PK Baby / Toddler Training Cup (Pink)
# 183529  Baby Food Freezer Tray - Bacteria Resistant, B...
# 183530  Best 2 Pack Baby Car Shade for Kids - Window S...
#
#                                                    review  rating  \
# 1       it came early and was not disappointed. i love...       5
# 2       Very soft and comfortable and warmer than it l...       5
# 3       This is a product well worth the purchase.  I ...       5
# 4       All of my kids have cried non-stop when I trie...       5
# 5       When the Binky Fairy came to our house, we did...       5
# 6       Lovely book, it\'s bound tightly so you may no...       4
# 7       Perfect for new parents. We were able to keep ...       5
# 8       A friend of mine pinned this product on Pinter...       5
# 9       This has been an easy way for my nanny to reco...       4
# 10      I love this journal and our nanny uses it ever...       4
# 11      This book is perfect!  I\'m a first time new m...       5
# 12      I originally just gave the nanny a pad of pape...       4
# 14      Space for monthly photos, info and a lot of us...       5
# 15      I bought this calender for myself for my secon...       4
# 16      I love this little calender, you can keep trac...       5
# 17      This was the only calender I could find for th...       5
# 18      I completed a calendar for my son\'s first yea...       4
# 19      We wanted to get something to keep track of ou...       5
# 20      I had a hard time finding a second year calend...       5
# 21      I only purchased a second-year calendar for my...       2
# 22      I LOVE this calendar for recording events of m...       5
# 24      Wife loves this calender. Comes with a lot of ...       5
# 25      My daughter had her 1st baby over a year ago. ...       5
# 26      Extremely useful! As a new mom, tired and inex...       5
# 28      One of baby\'s first and favorite books, and i...       4
# 29      I like how the book has a hook to attach it to...       5
# 30      Beautiful little book.  A great little short s...       5
# 31      This book is so worth the money. It says 9+ mo...       5
# 32      we just got this book for our one-year-old and...       5
# 33      The book is colorful and is perfect for 6month...       4
# ...                                                   ...     ...
# 183499  I received a free sample from VIPU program for...       5
# 183500  Great product, great company! Their daily give...       5
# 183501  I received a free sample from VIPU program for...       5
# 183502  It got here incredibly fast & it is a nice dur...       5
# 183503  I got this case in the mail today, it came on ...       2
# 183504  Free caseLove it... The color was great firm h...       5
# 183505  I received a free sample from VIPU program for...       5
# 183506  This case definitely isn\'t cheap. It feels ve...       5
# 183507  got this for my wife and she loves it would de...       5
# 183508  love this case. It fit perfectly and the color...       5
# 183509  this case is the greatest very cool and stylis...       5
# 183510              Great fit. Really love how red it is.       5
# 183512  *I received a free sample from VIPU program fo...       5
# 183513  I was a very surprised by the quality of this ...       5
# 183514  I received a free sample from VIPU program for...       4
# 183515  I love this phone case!  My  iPhone is always ...       5
# 183517  I recieved this product free of charge and abs...       5
# 183518  The tube is soft and easy to use, and the tip ...       5
# 183519  I love this so much. It works way better than ...       5
# 183520  The aspirator works well but needs to come wit...       4
# 183521  Up until recently I have hated flying, putting...       5
# 183522  I bought this as a father\'s day gift for my d...       5
# 183523  I love that these can hold purees OR liquids, ...       5
# 183524  I love this product, it makes my life easier. ...       5
# 183525  This reusable squeeze bottle is the best I hav...       5
# 183526  Such a great idea! very handy to have and look...       5
# 183527  This product rocks!  It is a great blend of fu...       5
# 183528  This item looks great and cool for my kids.......       5
# 183529  I am extremely happy with this product. I have...       5
# 183530  I love this product very mush . I have bought ...       5
#
#         review length  sentiment
# 1                 158          1
# 2                 143          1
# 3                 390          1
# 4                 405          1
# 5                 495          1
# 6                 217          1
# 7                 254          1
# 8                 196          1
# 9                 416          1
# 10               1012          1
# 11                252          1
# 12               1287          1
# 14                103          1
# 15                493          1
# 16                121          1
# 17                226          1
# 18                432          1
# 19                175          1
# 20                493          1
# 21                512         -1
# 22                528          1
# 24                330          1
# 25                394          1
# 26                149          1
# 28                186          1
# 29                130          1
# 30                210          1
# 31                202          1
# 32                350          1
# 33                204          1
# ...               ...        ...
# 183499            207          1
# 183500            249          1
# 183501            184          1
# 183502            196          1
# 183503            321         -1
# 183504            130          1
# 183505            160          1
# 183506            709          1
# 183507             72          1
# 183508             54          1
# 183509            116          1
# 183510             37          1
# 183512            253          1
# 183513            111          1
# 183514            341          1
# 183515            126          1
# 183517            294          1
# 183518            337          1
# 183519            211          1
# 183520            428          1
# 183521            396          1
# 183522            372          1
# 183523            523          1
# 183524            453          1
# 183525           1170          1
# 183526            138          1
# 183527            354          1
# 183528             93          1
# 183529            854          1
# 183530            196          1
#
# [166752 rows x 5 columns]

# %% [markdown]
# ## First split the data into traning set and testing set.

# %%
from sklearn.model_selection  import train_test_split
#First define the training set and the testing set. Testing set is used to evaluate the model
X_train, X_test, y_train, y_test = train_test_split(reviews_df,reviews_df.sentiment,test_size=0.2,random_state=1)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (133401, 5)
# (33351, 5)
# (133401L,)
# (33351L,)

# %% [markdown]
# ## Vectorizing our dataset

# %%
#References for  feature extraction using bag of words technique
#http://scikit-learn.org/stable/modules/feature_extraction.html#text-feature-extraction
#https://www.youtube.com/watch?v=ZiKMIuYidY0  - Reference youtube video. Very very good from Dataschool
#https://github.com/justmarkham/pycon-2016-tutorial - Look at tutorial.ipynb

# Import and instantiate the vectorizer
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(vocabulary=selected_words)

# Learn the vocabulary from the training data, then use it to create a document-term matrix
#This is again in-place
vectorizer.fit(X_train['review'])


X_train_dtm = vectorizer.transform(X_train['review'])
# equivalently: combine fit and transform into a single step
X_train_dtm = vectorizer.fit_transform(X_train['review'])

#Use the learned vocabulary and build the dtm for X_test
#You dont do a fit here as the vocabulary learned from the training set has to be used.
X_test_dtm = vectorizer.transform(X_test['review'])


#Examine the vocabulary and dtm together
#You encounter a memory error. However, this is the way to examine the DTM and features
#pd.DataFrame(X_train_dtm.toarray(),columns=vectorizer.get_feature_names())

# %% [markdown]
# ## Building and evaluating the model using logistic regression

# %%
#Import and instantiate a logistic regression model
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

# %%
#Train the model using X_train_dtm
logreg.fit(X_train_dtm, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
# make class predictions for X_test_dtm
y_pred_class = logreg.predict(X_test_dtm)

# %%
# calculate predicted probabilities for X_test_dtm (well calibrated)
y_pred_prob = logreg.predict_proba(X_test_dtm)[:, 1]
y_pred_prob
# Out:
# array([ 0.79079627,  0.97354921,  0.90147483, ...,  0.97354921,
#         0.90147483,  0.79079627])

# %%
# calculate accuracy of class predictions
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.84756079277982665

# %%
# calculate AUC
metrics.roc_auc_score(y_test, y_pred_prob)
# Out:
# 0.68650039258471462

# %%
X_test[y_pred_class == y_test]
# Out:
#                                                      name  \
# 178665  15 Plastic Alligator Grip Suspender Pacifier B...
# 158713  green sprouts 2 Count Cool Hand Teether, Green...
# 11916                   Kidkusion Kid Safe Banister Guard
# 55010                  Mommy\'s Helper Car Seat Sun Shade
# 44239   Gerber Graduates BPA Free 4 Pack Bunch-A-Bowls...
# 138343                Gerber 12 Pack Wash Cloth Set, Blue
# 170161  Pura Kiki Stainless Infant Bottle Stainless St...
# 117226  Summer Infant Disney Water Squirters, Winnie t...
# 102353   Skip Hop Zoo Lunchie Insulated Lunch Bag, Monkey
# 42744       Stairway Gate Installation Kit (K12) by KidCo
# 117165       Lassig Glam Small Messenger Diaper Bag ,navy
# 30667   BOB Weather Shield for Single Revolution/Strol...
# 60268                Tiny Love Sweet Island Dreams Mobile
# 150724     Britax Head and Body Support Pillow, Iron/Gray
# 78365                       Boon Splat Floating Ring Toss
# 130973  Fisher-Price Kick and Play Piano Gym, Discover...
# 22086   Medela PersonalFit Breastshields (2/pack) - La...
# 173932  NUK Gerber GraduatesAdvance Hard Spout Sippy C...
# 43673                            Totseat - Stripe in Blue
# 176077                            1D 62 x 90 inch Blanket
# 124195   Philips AVENT BPA Free Twin Electric Breast Pump
# 141034  Snappity Snap Monthly Baby Onesie Stickers (So...
# 163854               Edushape Edu-Fit Series Training Mat
# 4853                          Playmobil 5719 Nativity Set
# 29990                             Ameda White Adapter Cap
# 182394  SoHo Collection, Pink Zebra 6 pieces Diaper Ba...
# 4899    Safety 1st 900 Mhz Sight And Sound Nursery Mon...
# 88842   Mommy\'s Helper Step Up Non-Slip Stepstool Fro...
# 165178  aden + anais 2 Pack Rayon From Bamboo Issie Se...
# 6490                      Eddie Bauer Car Seat Travel Bag
# ...                                                   ...
# 110863                   Boppy Prenatal Total Body Pillow
# 138734         BRICA Infant Comfort Canopy Car Seat Cover
# 104238  Angel Dear Pair and a Spare 3 Piece Blanket Se...
# 127905      Graco Blossom 4-In-1 Seating System, Sapphire
# 90781   Safety 1st Air Protect On Board 35 Infant Car ...
# 94002             The First Years Jet Stroller, Red/Black
# 120435  Neat SolutionsDisney Princess Potty Topper, 10...
# 6991         Philips AVENT Washable Nursing Pads, 6-Count
# 96602   Thermos FOOGO Phases Straw Bottle, Blue/Yellow...
# 126246            green sprouts Insulated Snack Bag, Pink
# 179003           ChooMee Sip\'n Soft Top - Red and Purple
# 7393    The First Year\'s Infant To Toddler Tub with S...
# 135327  Disney Toddler Nap Mat with Coral Fleece Blank...
# 36475     Leachco All Nighter - Total Body Pillow - Ivory
# 128737  NUK Gerber Graduates Learning System Sports Le...
# 125457                    Soft Gear My Booster Seat, Mint
# 170763  HALO SleepSack Micro Fleece Swaddle Blanket, P...
# 43735                         TUPPERWARE Shape O Ball Toy
# 34326                    Vulli Sophie the Giraffe Teether
# 34515                    Vulli Sophie the Giraffe Teether
# 119950                 Playtex VentAire Replacement Disks
# 27507   Fisher-Price Rainforest Melodies and Lights De...
# 78592   Edushape Textured Brightly Colored Foam Buildi...
# 38467   Graco Pack \'N Play Playard with Bassinet in R...
# 95063   Snoogle Chic Cover - Replacement Cover in Sunn...
# 147269               BRICA Super Scoop Bath Toy Organizer
# 3985    Philips AVENT BPA Free Classic Newborn Flow Ni...
# 167406       Mountain Buggy 2013 Terrain Stroller (Flint)
# 52456   Sunshine Kids Monterey Booster Car Seat - Mont...
# 130735  Summer Infant Best View Handheld Color Video M...
#
#                                                    review  rating  \
# 178665  These clips are just what I was looking for.  ...       5
# 158713  This was a great buy, the baby really loves ch...       5
# 11916   It\'s a little amusing that this is marketed a...       5
# 55010   I live an area of the US where we get summers ...       5
# 44239   I ordered these to give to my daughter - she l...       5
# 138343  These were much softer than I thought. I have ...       5
# 170161  Pros:Stainless steel and silicone throughout -...       4
# 117226  These were so cheap and my son loves them! The...       5
# 102353  Lovely! I use with 2 thermos ice mats (one 9 c...       5
# 42744   It is a quality product and totally met our ex...       5
# 117165  While I\'m sure this bag is a wonderful diaper...       5
# 30667   This weather shield has been a great accessory...       5
# 60268   And we managed to get it to attach to the Grac...       5
# 150724  My son is 10 months old and still uses this. H...       4
# 78365   My soon to be 6 month old grandson took to thi...       5
# 130973  The same day I got this, I set it up (which wa...       5
# 22086   My local Babies-R-Us and Target stores did not...       5
# 173932  These are actually the best cups ever.  They d...       5
# 43673   What a great extra set of hands.  We go on a l...       5
# 176077  The blanket was a great size and super soft......       5
# 124195  Breast pump will be tested in mid September.  ...       5
# 141034  Great product..speedy delivery...they look ado...       5
# 163854  I let my daughter roll around on this mat befo...       4
# 4853    I work at a religious school, and I bought thi...       5
# 29990   These caps replaced the originals from the col...       5
# 182394  Beautiful bag. Bought this for my sister in la...       5
# 4899    We were very skeptical of owning a video monit...       5
# 88842   I bought this for grandma, just right, in fron...       5
# 165178  My four month old loves these blankies! He lov...       4
# 6490    We have twins and we took our first plane trip...       5
# ...                                                   ...     ...
# 110863  This pillow has been a life saver for me. Mone...       5
# 138734  Works great and it is easy to get on and off. ...       4
# 104238  Our son received the frog as a gift and it ins...       4
# 127905             Love this highchair, cleans up easily!       4
# 90781   I have been using this carseat with my now 3 w...       5
# 94002   I just bought the Jet for my 4 year old son fo...       4
# 120435  We use these in combination with our training ...       5
# 6991    Absorbed a little, but then milk leaks out fro...       1
# 96602   Hard to clean and eventually I have to throw o...       4
# 126246  Great little snack bag. Can fit a boxed milk, ...       5
# 179003  We love these tops for the refillable pouches ...       5
# 7393    Our 1 month old loves taking bath in this. Qua...       5
# 135327  I just received this today and my daughter, wh...       4
# 36475   I\'m 5\'9" and 5 months pregnant and have been...       5
# 128737  Can\'t say it enough - I love these cups!  We ...       5
# 125457  Great seat! Love how well it grips the chair a...       5
# 170763  I loved this so much I bought another one a co...       5
# 43735   As a pre-school teacher, I recognize that the ...       5
# 34326                                                           5
# 34515   As every mom knows, you always want to give yo...       5
# 119950  before placing them back into the bottoms of y...       4
# 27507   My child loves this item. The lights and the a...       5
# 78592   I bought a bag of these last Christmas for my ...       5
# 38467   I purchased this based on my daughter\'s recom...       5
# 95063   A friend gave me the Snoogle pillow she owned ...       4
# 147269  Great find! Keeps bath toys stored and dry whe...       5
# 3985    these nipples work great except i wasn\'t sure...       4
# 167406  Love this stroller so far. Daughter falls asle...       5
# 52456   I just can\'t say enough good things about thi...       5
# 130735  We already had the older model ... and bought ...       5
#
#         review length  sentiment
# 178665            120          1
# 158713            125          1
# 11916             822          1
# 55010             437          1
# 44239             241          1
# 138343            139          1
# 170161            669          1
# 117226            111          1
# 102353            737          1
# 42744             124          1
# 117165            349          1
# 30667             949          1
# 60268             902          1
# 150724            101          1
# 78365             294          1
# 130973            195          1
# 22086             144          1
# 173932            187          1
# 43673             398          1
# 176077            103          1
# 124195             91          1
# 141034            145          1
# 163854            402          1
# 4853              525          1
# 29990             302          1
# 182394            165          1
# 4899              770          1
# 88842             116          1
# 165178            252          1
# 6490              483          1
# ...               ...        ...
# 110863            402          1
# 138734            214          1
# 104238            730          1
# 127905             38          1
# 90781             587          1
# 94002             770          1
# 120435            163          1
# 6991              104         -1
# 96602             197          1
# 126246            143          1
# 179003            110          1
# 7393              118          1
# 135327            422          1
# 36475            1830          1
# 128737           1220          1
# 125457            101          1
# 170763            491          1
# 43735             310          1
# 34326               0          1
# 34515            1392          1
# 119950            143          1
# 27507             356          1
# 78592             242          1
# 38467             384          1
# 95063             695          1
# 147269            113          1
# 3985              415          1
# 167406            217          1
# 52456            1082          1
# 130735            240          1
#
# [28267 rows x 5 columns]

# %% [markdown]
# ## Print the document term matrix for the training set

# %%
#pd.DataFrame(X_train_dtm.toarray(),columns=vectorizer.get_feature_names())

# %% [markdown]
# ## Print the column names in the X_train_dtm

# %%
#print the column names in the X_train_dtm
columns=vectorizer.get_feature_names()
print(columns)
# Out:
# ['awesome', 'great', 'fantastic', 'amazing', 'love', 'horrible', 'bad', 'terrible', 'awful', 'wow', 'hate']

# %% [markdown]
# ## Print the weights learned by the classifier

# %%
#https://stackoverflow.com/questions/47303261/getting-weights-of-features-using-scikit-learn-logistic-regression
#The coefficient array is the list of coefficient values. 
#The values are ordered by the order of columns in your X_train dataset.
coef = logreg.coef_[0]
print (coef)
# Out:
# [ 1.2264206   0.8839883   0.9133578   1.07063568  1.39194209 -2.24692436
#  -1.00144791 -2.22244556 -2.05852225 -0.10411529 -1.42709769]
